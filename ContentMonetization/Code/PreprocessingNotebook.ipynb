# %% [markdown]
# # 06 April 2024

# %%
import pandas as pd

df = pd.read_csv(r"..\Data\youtube_ad_revenue_dataset.csv")
df
# Out:
#         video_id                        date  views   likes  comments  \
# 0       vid_3092  2024-09-24 10:50:40.993199   9936  1221.0     320.0
# 1       vid_3459  2024-09-22 10:50:40.993199  10017   642.0     346.0
# 2       vid_4784  2024-11-21 10:50:40.993199  10097  1979.0     187.0
# 3       vid_4078  2025-01-28 10:50:40.993199  10034  1191.0     242.0
# 4       vid_3522  2025-04-28 10:50:40.993199   9889  1858.0     477.0
# ...          ...                         ...    ...     ...       ...
# 122395  vid_2902  2024-12-14 10:50:40.993199   9853  1673.0     147.0
# 122396  vid_3890  2024-07-13 10:50:40.993199  10128  1709.0      63.0
# 122397  vid_3934  2024-06-10 10:50:40.993199  10267   700.0       NaN
# 122398  vid_4260  2024-12-22 10:50:40.993199  10240  1616.0     106.0
# 122399  vid_1056  2024-06-25 10:50:40.993199   9931   770.0       NaN
#
#         watch_time_minutes  video_length_minutes  subscribers       category  \
# ...

# %%
df_copy = df.copy()

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122400 entries, 0 to 122399
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   video_id              122400 non-null  object
#  1   date                  122400 non-null  object
#  2   views                 122400 non-null  int64
#  3   likes                 116283 non-null  float64
#  4   comments              116288 non-null  float64
#  5   watch_time_minutes    116295 non-null  float64
#  6   video_length_minutes  122400 non-null  float64
#  7   subscribers           122400 non-null  int64
#  8   category              122400 non-null  object
#  9   device                122400 non-null  object
#  10  country               122400 non-null  object
#  11  ad_revenue_usd        122400 non-null  float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 11.2+ MB

# %%
df_copy.shape
# Out:
# (122400, 12)

# %%
df_copy.isnull().sum()
# Out:
# video_id                   0
# date                       0
# views                      0
# likes                   6117
# comments                6112
# watch_time_minutes      6105
# video_length_minutes       0
# subscribers                0
# category                   0
# device                     0
# country                    0
# ad_revenue_usd             0
# dtype: int64

# %%
df_copy.isna().sum()*100/len(df_copy)
# Out:
# video_id                0.000000
# date                    0.000000
# views                   0.000000
# likes                   4.997549
# comments                4.993464
# watch_time_minutes      4.987745
# video_length_minutes    0.000000
# subscribers             0.000000
# category                0.000000
# device                  0.000000
# country                 0.000000
# ad_revenue_usd          0.000000
# dtype: float64

# %%
df_copy[df_copy[['likes','comments','watch_time_minutes']].isna().all(axis=1)]
# Out:
#         video_id                        date  views  likes  comments  \
# 5469    vid_4475  2024-06-21 10:50:40.993199  10139    NaN       NaN
# 11507   vid_3668  2024-08-31 10:50:40.993199   9957    NaN       NaN
# 16545   vid_2601  2025-03-31 10:50:40.993199   9952    NaN       NaN
# 35260   vid_4105  2025-01-07 10:50:40.993199   9978    NaN       NaN
# 45723   vid_4036  2025-04-11 10:50:40.993199   9918    NaN       NaN
# 53325   vid_2594  2024-12-12 10:50:40.993199   9987    NaN       NaN
# 55760   vid_3761  2025-01-05 10:50:40.993199   9874    NaN       NaN
# 58162   vid_2219  2025-06-01 10:50:40.993199  10080    NaN       NaN
# 87233   vid_4083  2025-04-13 10:50:40.993199  10124    NaN       NaN
# 87248   vid_1953  2024-06-15 10:50:40.993199   9841    NaN       NaN
# 92566   vid_4135  2025-03-10 10:50:40.993199  10035    NaN       NaN
# 92575    vid_353  2025-02-23 10:50:40.993199   9861    NaN       NaN
# 93428   vid_2839  2025-05-29 10:50:40.993199  10154    NaN       NaN
# ...

# %%
df_copy=df_copy.dropna(subset=['likes','comments','watch_time_minutes'], how='all')

# %%
df_copy['watch_time_minutes'].isna().sum()
# Out:
# np.int64(6087)

# %%
df_copy=df_copy.fillna({'watch_time_minutes':df_copy['watch_time_minutes'].median()})

# %%
null_value_status = df_copy.isna().sum()*100/len(df_copy)
null_value_status
# Out:
# video_id                0.000000
# date                    0.000000
# views                   0.000000
# likes                   4.983576
# comments                4.979490
# watch_time_minutes      0.000000
# video_length_minutes    0.000000
# subscribers             0.000000
# category                0.000000
# device                  0.000000
# country                 0.000000
# ad_revenue_usd          0.000000
# dtype: float64

# %%
df_copy[df_copy[['likes','comments']].isna().all(axis=1)]
# Out:
#         video_id                        date  views  likes  comments  \
# 368     vid_3569  2024-12-07 10:50:40.993199  10143    NaN       NaN
# 545     vid_2410  2025-04-25 10:50:40.993199   9989    NaN       NaN
# 1029     vid_399  2024-09-20 10:50:40.993199   9919    NaN       NaN
# 1738     vid_974  2025-03-14 10:50:40.993199  10098    NaN       NaN
# 1875    vid_2046  2024-07-05 10:50:40.993199   9857    NaN       NaN
# ...          ...                         ...    ...    ...       ...
# 120597  vid_3576  2024-10-02 10:50:40.993199   9983    NaN       NaN
# 120720  vid_2224  2024-07-21 10:50:40.993199  10204    NaN       NaN
# 120860  vid_4201  2024-11-26 10:50:40.993199   9946    NaN       NaN
# 121037  vid_3712  2025-01-04 10:50:40.993199  10057    NaN       NaN
# 121981  vid_1298  2025-05-07 10:50:40.993199  10142    NaN       NaN
#
#         watch_time_minutes  video_length_minutes  subscribers       category  \
# ...

# %%
df_copy=df_copy.dropna(subset=['likes','comments'], how='all')

# %%
null_value_status = df_copy.isna().sum()*100/len(df_copy)
null_value_status
# Out:
# video_id                0.000000
# date                    0.000000
# views                   0.000000
# likes                   4.757107
# comments                4.753012
# watch_time_minutes      0.000000
# video_length_minutes    0.000000
# subscribers             0.000000
# category                0.000000
# device                  0.000000
# country                 0.000000
# ad_revenue_usd          0.000000
# dtype: float64

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 122091 entries, 0 to 122399
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   video_id              122091 non-null  object
#  1   date                  122091 non-null  object
#  2   views                 122091 non-null  int64
#  3   likes                 116283 non-null  float64
#  4   comments              116288 non-null  float64
#  5   watch_time_minutes    122091 non-null  float64
#  6   video_length_minutes  122091 non-null  float64
#  7   subscribers           122091 non-null  int64
#  8   category              122091 non-null  object
#  9   device                122091 non-null  object
#  10  country               122091 non-null  object
#  11  ad_revenue_usd        122091 non-null  float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 12.1+ MB

# %%
df_copy.duplicated().sum()
# Out:
# np.int64(2400)

# %%
df_copy
# Out:
#         video_id                        date  views   likes  comments  \
# 0       vid_3092  2024-09-24 10:50:40.993199   9936  1221.0     320.0
# 1       vid_3459  2024-09-22 10:50:40.993199  10017   642.0     346.0
# 2       vid_4784  2024-11-21 10:50:40.993199  10097  1979.0     187.0
# 3       vid_4078  2025-01-28 10:50:40.993199  10034  1191.0     242.0
# 4       vid_3522  2025-04-28 10:50:40.993199   9889  1858.0     477.0
# ...          ...                         ...    ...     ...       ...
# 122395  vid_2902  2024-12-14 10:50:40.993199   9853  1673.0     147.0
# 122396  vid_3890  2024-07-13 10:50:40.993199  10128  1709.0      63.0
# 122397  vid_3934  2024-06-10 10:50:40.993199  10267   700.0       NaN
# 122398  vid_4260  2024-12-22 10:50:40.993199  10240  1616.0     106.0
# 122399  vid_1056  2024-06-25 10:50:40.993199   9931   770.0       NaN
#
#         watch_time_minutes  video_length_minutes  subscribers       category  \
# ...

# %%
df_copy['date']=pd.to_datetime(df_copy['date']).dt.floor('s')

# %%
df_copy['likes'] = df_copy['likes'].fillna(0)
df_copy['likes'] = df_copy['likes'].astype(int)
df_copy['comments'] = df_copy['comments'].fillna(0)
df_copy['comments'] = df_copy['comments'].astype(int)

# %%
null_value_status = df_copy.isna().sum()*100/len(df_copy)
null_value_status
# Out:
# video_id                0.0
# date                    0.0
# views                   0.0
# likes                   0.0
# comments                0.0
# watch_time_minutes      0.0
# video_length_minutes    0.0
# subscribers             0.0
# category                0.0
# device                  0.0
# country                 0.0
# ad_revenue_usd          0.0
# dtype: float64

# %%
df_copy.duplicated().sum()
# Out:
# np.int64(2395)

# %%
df_copy[df_copy.duplicated()]
# Out:
#         video_id                        date  views   likes  comments  \
# 3179    vid_4608  2025-01-11 10:50:40.993199   9945  1458.0     121.0
# 3231    vid_3134  2025-06-05 10:50:40.993199  10077   701.0     202.0
# 3666      vid_25  2024-09-18 10:50:40.993199   9947  1802.0     347.0
# 4710    vid_4926  2024-10-24 10:50:40.993199   9995  1286.0     292.0
# 4818    vid_4966  2025-02-10 10:50:40.993199  10034   776.0     447.0
# ...          ...                         ...    ...     ...       ...
# 122163  vid_4644  2024-08-25 10:50:40.993199  10047  1948.0     307.0
# 122237  vid_2558  2024-07-27 10:50:40.993199  10028  1273.0     149.0
# 122263  vid_4264  2024-09-30 10:50:40.993199  10035   563.0     457.0
# 122269  vid_2012  2025-06-07 10:50:40.993199   9919   688.0     152.0
# 122337  vid_1985  2025-05-17 10:50:40.993199   9924     NaN     373.0
#
#         watch_time_minutes  video_length_minutes  subscribers       category  \
# ...

# %%
df_copy[df_copy.duplicated(keep=False)].sort_values(by=['video_id','date'])
# Out:
#         video_id                date  views  likes  comments  \
# 27583     vid_10 2024-11-25 10:50:40  10001   1877       316
# 101218    vid_10 2024-11-25 10:50:40  10001   1877       316
# 62274   vid_1003 2024-08-24 10:50:40  10038   1983         0
# 121655  vid_1003 2024-08-24 10:50:40  10038   1983         0
# 69681   vid_1003 2025-01-18 10:50:40  10010   1502       182
# ...          ...                 ...    ...    ...       ...
# 98228    vid_996 2024-10-31 10:50:40   9753    242       476
# 51660    vid_997 2025-04-25 10:50:40   9993   1970       185
# 86871    vid_997 2025-04-25 10:50:40   9993   1970       185
# 48302    vid_999 2024-09-15 10:50:40   9860   1541       472
# 60773    vid_999 2024-09-15 10:50:40   9860   1541       472
#
#         watch_time_minutes  video_length_minutes  subscribers   category  \
# 27583         45099.652444             26.862350       653429  Lifestyle
# 101218        45099.652444             26.862350       653429  Lifestyle
# ...

# %%
# delete the duplicate rows and keep the first occurrence
df_copy=df_copy.drop_duplicates(keep='first')

# %%
df_copy[df_copy.duplicated(keep=False)].sort_values(by=['video_id','date'])
# Out:
# Empty DataFrame
# Columns: [video_id, date, views, likes, comments, watch_time_minutes, video_length_minutes, subscribers, category, device, country, ad_revenue_usd]
# Index: []

# %%
df_copy[df_copy['likes'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [video_id, date, views, likes, comments, watch_time_minutes, video_length_minutes, subscribers, category, device, country, ad_revenue_usd]
# Index: []

# %%
df_copy[df_copy['video_id']=='vid_4434']
# Out:
#         video_id                date  views  likes  comments  \
# 9       vid_4434 2025-04-16 10:50:40  10051      0        61
# 831     vid_4434 2024-10-21 10:50:40  10032    552       380
# 3402    vid_4434 2025-03-31 10:50:40   9958   1870        49
# 6617    vid_4434 2025-02-23 10:50:40  10025      0       268
# 6679    vid_4434 2024-08-09 10:50:40  10226   1885       279
# 8756    vid_4434 2025-01-08 10:50:40   9973   1146       130
# 11413   vid_4434 2024-06-14 10:50:40   9934   1756       303
# 21623   vid_4434 2024-11-03 10:50:40   9710    679       101
# 23455   vid_4434 2024-12-06 10:50:40   9845   1588       346
# 26819   vid_4434 2025-05-23 10:50:40   9966   1785       194
# 33920   vid_4434 2025-04-12 10:50:40   9938    843       276
# 39666   vid_4434 2025-02-13 10:50:40   9896   1677       397
# 42648   vid_4434 2025-03-23 10:50:40  10024   1038       153
# 48117   vid_4434 2024-10-17 10:50:40  10001   1799       439
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119696 entries, 0 to 122399
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   video_id              119696 non-null  object
#  1   date                  119696 non-null  datetime64[ns]
#  2   views                 119696 non-null  int64
#  3   likes                 119696 non-null  int64
#  4   comments              119696 non-null  int64
#  5   watch_time_minutes    119696 non-null  float64
#  6   video_length_minutes  119696 non-null  float64
#  7   subscribers           119696 non-null  int64
#  8   category              119696 non-null  object
#  9   device                119696 non-null  object
#  10  country               119696 non-null  object
#  11  ad_revenue_usd        119696 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(4)
# memory usage: 11.9+ MB

# %%
df_copy.describe()
# Out:
#                                 date          views          likes  \
# count                         119696  119696.000000  119696.000000
# mean   2024-12-08 03:32:06.459030016    9999.817730    1047.258847
# min              2024-06-09 10:50:40    9521.000000       0.000000
# 25%              2024-09-07 10:50:40    9933.000000     581.000000
# 50%              2024-12-08 10:50:40   10000.000000    1056.000000
# 75%              2025-03-09 10:50:40   10067.000000    1525.000000
# max              2025-06-08 10:50:40   10468.000000    2061.000000
# std                              NaN      99.926834     558.447201
#
#             comments  watch_time_minutes  video_length_minutes    subscribers  \
# count  119696.000000       119696.000000         119696.000000  119696.000000
# mean      261.294296        37540.553649             16.018134  502254.472998
# min         0.000000        14659.105562              2.000142    1005.000000
# ...

# %%
df_copy['watch_time_hours'] = df_copy['watch_time_minutes']/60
# Out:
# C:\Users\nisha\AppData\Local\Temp\ipykernel_25828\1509193164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy['watch_time_hours'] = df_copy['watch_time_minutes']/60

# %%
df_copy
# Out:
#         video_id                date  views  likes  comments  \
# 0       vid_3092 2024-09-24 10:50:40   9936   1221       320
# 1       vid_3459 2024-09-22 10:50:40  10017    642       346
# 2       vid_4784 2024-11-21 10:50:40  10097   1979       187
# 3       vid_4078 2025-01-28 10:50:40  10034   1191       242
# 4       vid_3522 2025-04-28 10:50:40   9889   1858       477
# ...          ...                 ...    ...    ...       ...
# 122395  vid_2902 2024-12-14 10:50:40   9853   1673       147
# 122396  vid_3890 2024-07-13 10:50:40  10128   1709        63
# 122397  vid_3934 2024-06-10 10:50:40  10267    700         0
# 122398  vid_4260 2024-12-22 10:50:40  10240   1616       106
# 122399  vid_1056 2024-06-25 10:50:40   9931    770         0
#
#         watch_time_minutes  video_length_minutes  subscribers       category  \
# 0             26497.214184              2.862137       228086  Entertainment
# ...

# %%
df_copy['category'].unique()
# Out:
# array(['Entertainment', 'Gaming', 'Education', 'Music', 'Tech',
#        'Lifestyle'], dtype=object)

# %%
# Frequency encoding
frequency_encoding = df_copy['category'].value_counts()
frequency_encoding
# Out:
# category
# Education        20073
# Music            20005
# Tech             19982
# Entertainment    19974
# Gaming           19921
# Lifestyle        19741
# Name: count, dtype: int64

# %%
# Frequency encoding
frequency_encoding = df_copy['category'].value_counts()
df_copy['category_encoded'] = df_copy['category'].map(frequency_encoding)
# Out:
# C:\Users\nisha\AppData\Local\Temp\ipykernel_25828\1923570252.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy['category_encoded'] = df_copy['category'].map(frequency_encoding)

# %%
df_copy['category_encoded'].unique()
# Out:
# array([19974, 19921, 20073, 20005, 19982, 19741])

# %%
#Which content type is most common on the platform?
df_copy.groupby('category_encoded')['watch_time_hours'].mean()
# Out:
# category_encoded
# 19741    623.214573
# 19921    628.057326
# 19974    624.727168
# 19982    628.313332
# 20005    624.700688
# 20073    625.023575
# Name: watch_time_hours, dtype: float64

# %%
df_copy['device'].unique()
# Out:
# array(['TV', 'Tablet', 'Mobile', 'Desktop'], dtype=object)

# %%
df_copy['country'].unique()
# Out:
# array(['IN', 'CA', 'UK', 'US', 'DE', 'AU'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
encoder =LabelEncoder()
df_copy['device_encoded']=encoder.fit_transform(df_copy['device'])
df_copy['country_encoded']=encoder.fit_transform(df_copy['country'])
# Out:
# C:\Users\nisha\AppData\Local\Temp\ipykernel_25828\4019490764.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy['device_encoded']=encoder.fit_transform(df_copy['device'])
# C:\Users\nisha\AppData\Local\Temp\ipykernel_25828\4019490764.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy['country_encoded']=encoder.fit_transform(df_copy['country'])

# %%
df_copy.isnull().sum()
# Out:
# video_id                0
# date                    0
# views                   0
# likes                   0
# comments                0
# watch_time_minutes      0
# video_length_minutes    0
# subscribers             0
# category                0
# device                  0
# country                 0
# ad_revenue_usd          0
# watch_time_hours        0
# category_encoded        0
# device_encoded          0
# country_encoded         0
# dtype: int64

# %%
df_copy.head()
# Out:
#    video_id                date  views  likes  comments  watch_time_minutes  \
# 0  vid_3092 2024-09-24 10:50:40   9936   1221       320        26497.214184
# 1  vid_3459 2024-09-22 10:50:40  10017    642       346        15209.747445
# 2  vid_4784 2024-11-21 10:50:40  10097   1979       187        57332.658498
# 3  vid_4078 2025-01-28 10:50:40  10034   1191       242        31334.517771
# 4  vid_3522 2025-04-28 10:50:40   9889   1858       477        15665.666434
#
#    video_length_minutes  subscribers       category  device country  \
# 0              2.862137       228086  Entertainment      TV      IN
# 1             23.738069       736015         Gaming  Tablet      CA
# 2             26.200634       240534      Education      TV      CA
# 3             11.770340       434482  Entertainment  Mobile      UK
# 4              6.635854        42030      Education  Mobile      CA
#
#    ad_revenue_usd  watch_time_hours  category_encoded  device_encoded  \
# ...

# %%
df_copy['engagement_rate'] = (df_copy['likes'] + df_copy['comments']) / df_copy['views']
# Out:
# C:\Users\nisha\AppData\Local\Temp\ipykernel_25828\1199988168.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy['engagement_rate'] = (df_copy['likes'] + df_copy['comments']) / df_copy['views']

# %%
df_copy.head()
# Out:
#    video_id                date  views  likes  comments  watch_time_minutes  \
# 0  vid_3092 2024-09-24 10:50:40   9936   1221       320        26497.214184
# 1  vid_3459 2024-09-22 10:50:40  10017    642       346        15209.747445
# 2  vid_4784 2024-11-21 10:50:40  10097   1979       187        57332.658498
# 3  vid_4078 2025-01-28 10:50:40  10034   1191       242        31334.517771
# 4  vid_3522 2025-04-28 10:50:40   9889   1858       477        15665.666434
#
#    video_length_minutes  subscribers       category  device country  \
# 0              2.862137       228086  Entertainment      TV      IN
# 1             23.738069       736015         Gaming  Tablet      CA
# 2             26.200634       240534      Education      TV      CA
# 3             11.770340       434482  Entertainment  Mobile      UK
# 4              6.635854        42030      Education  Mobile      CA
#
#    ad_revenue_usd  watch_time_hours  category_encoded  device_encoded  \
# ...

# %%
df_copy.isnull().sum()
# Out:
# video_id                0
# date                    0
# views                   0
# likes                   0
# comments                0
# watch_time_minutes      0
# video_length_minutes    0
# subscribers             0
# category                0
# device                  0
# country                 0
# ad_revenue_usd          0
# watch_time_hours        0
# category_encoded        0
# device_encoded          0
# country_encoded         0
# engagement_rate         0
# dtype: int64

# %%
df.shape
# Out:
# (122400, 12)

# %%
df_copy.shape
# Out:
# (119696, 17)

# %%
df_copy.to_csv(r"../Data/Cleaned_youtube_ad_revenue_dataset.csv", index=False)

# %% [markdown]
# # 17 April 2026

# %%
import pandas as pd

df = pd.read_csv(r"..\Data\youtube_ad_revenue_dataset.csv")
df
# Out:
#         video_id                        date  views   likes  comments  \
# 0       vid_3092  2024-09-24 10:50:40.993199   9936  1221.0     320.0
# 1       vid_3459  2024-09-22 10:50:40.993199  10017   642.0     346.0
# 2       vid_4784  2024-11-21 10:50:40.993199  10097  1979.0     187.0
# 3       vid_4078  2025-01-28 10:50:40.993199  10034  1191.0     242.0
# 4       vid_3522  2025-04-28 10:50:40.993199   9889  1858.0     477.0
# ...          ...                         ...    ...     ...       ...
# 122395  vid_2902  2024-12-14 10:50:40.993199   9853  1673.0     147.0
# 122396  vid_3890  2024-07-13 10:50:40.993199  10128  1709.0      63.0
# 122397  vid_3934  2024-06-10 10:50:40.993199  10267   700.0       NaN
# 122398  vid_4260  2024-12-22 10:50:40.993199  10240  1616.0     106.0
# 122399  vid_1056  2024-06-25 10:50:40.993199   9931   770.0       NaN
#
#         watch_time_minutes  video_length_minutes  subscribers       category  \
# ...

# %%
df_copy = df.copy()

# %%
df_copy
# Out:
#         video_id                        date  views   likes  comments  \
# 0       vid_3092  2024-09-24 10:50:40.993199   9936  1221.0     320.0
# 1       vid_3459  2024-09-22 10:50:40.993199  10017   642.0     346.0
# 2       vid_4784  2024-11-21 10:50:40.993199  10097  1979.0     187.0
# 3       vid_4078  2025-01-28 10:50:40.993199  10034  1191.0     242.0
# 4       vid_3522  2025-04-28 10:50:40.993199   9889  1858.0     477.0
# ...          ...                         ...    ...     ...       ...
# 122395  vid_2902  2024-12-14 10:50:40.993199   9853  1673.0     147.0
# 122396  vid_3890  2024-07-13 10:50:40.993199  10128  1709.0      63.0
# 122397  vid_3934  2024-06-10 10:50:40.993199  10267   700.0       NaN
# 122398  vid_4260  2024-12-22 10:50:40.993199  10240  1616.0     106.0
# 122399  vid_1056  2024-06-25 10:50:40.993199   9931   770.0       NaN
#
#         watch_time_minutes  video_length_minutes  subscribers       category  \
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122400 entries, 0 to 122399
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   video_id              122400 non-null  object
#  1   date                  122400 non-null  object
#  2   views                 122400 non-null  int64
#  3   likes                 116283 non-null  float64
#  4   comments              116288 non-null  float64
#  5   watch_time_minutes    116295 non-null  float64
#  6   video_length_minutes  122400 non-null  float64
#  7   subscribers           122400 non-null  int64
#  8   category              122400 non-null  object
#  9   device                122400 non-null  object
#  10  country               122400 non-null  object
#  11  ad_revenue_usd        122400 non-null  float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 11.2+ MB

# %%
df_copy.isnull().sum()
# Out:
# video_id                   0
# date                       0
# views                      0
# likes                   6117
# comments                6112
# watch_time_minutes      6105
# video_length_minutes       0
# subscribers                0
# category                   0
# device                     0
# country                    0
# ad_revenue_usd             0
# dtype: int64

# %%
df_copy=df_copy.dropna(subset=['likes','comments','watch_time_minutes'], how='all') 
df_copy=df_copy.dropna(subset=['likes','comments'], how='all') 
df_copy=df_copy.fillna({'watch_time_minutes':df_copy['watch_time_minutes'].median()})
df_copy['likes'] = df_copy['likes'].fillna(0)
df_copy['likes'] = df_copy['likes'].astype(int)
df_copy['comments'] = df_copy['comments'].fillna(0)
df_copy['comments'] = df_copy['comments'].astype(int)

# %%
df_copy.isnull().sum()
# Out:
# video_id                0
# date                    0
# views                   0
# likes                   0
# comments                0
# watch_time_minutes      0
# video_length_minutes    0
# subscribers             0
# category                0
# device                  0
# country                 0
# ad_revenue_usd          0
# dtype: int64

# %%
df_copy.duplicated().sum()
# Out:
# np.int64(2395)

# %%
df_copy=df_copy.drop_duplicates(keep='first')

# %%
df_copy.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119696 entries, 0 to 122399
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   video_id              119696 non-null  object
#  1   date                  119696 non-null  object
#  2   views                 119696 non-null  int64
#  3   likes                 119696 non-null  int64
#  4   comments              119696 non-null  int64
#  5   watch_time_minutes    119696 non-null  float64
#  6   video_length_minutes  119696 non-null  float64
#  7   subscribers           119696 non-null  int64
#  8   category              119696 non-null  object
#  9   device                119696 non-null  object
#  10  country               119696 non-null  object
#  11  ad_revenue_usd        119696 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 11.9+ MB

# %%
df_copy['video_id'] = pd.to_numeric(df_copy['video_id'].str.replace('vid_', ''),errors='coerce')

# %%
df_copy['date']=pd.to_datetime(df_copy['date']).dt.floor('s')

# %%
df_copy['category'].unique()
# Out:
# array(['Entertainment', 'Gaming', 'Education', 'Music', 'Tech',
#        'Lifestyle'], dtype=object)

# %%
df_copy['device'].unique()
# Out:
# array(['TV', 'Tablet', 'Mobile', 'Desktop'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
encoder =LabelEncoder()
df_copy['category']=pd.to_numeric(encoder.fit_transform(df_copy['category']),errors='coerce')
df_copy['device']=pd.to_numeric(encoder.fit_transform(df_copy['device']),errors='coerce')

# %%
df_copy['country'].unique()
# Out:
# array(['IN', 'CA', 'UK', 'US', 'DE', 'AU'], dtype=object)

# %%
df_copy=df_copy.drop(columns=['country'], axis=1)

# %%
df_copy['engagement_rate'] = (df_copy['likes'] + df_copy['comments']) / df_copy['views']

# %%
df_copy
# Out:
#         video_id                date  views  likes  comments  \
# 0           3092 2024-09-24 10:50:40   9936   1221       320
# 1           3459 2024-09-22 10:50:40  10017    642       346
# 2           4784 2024-11-21 10:50:40  10097   1979       187
# 3           4078 2025-01-28 10:50:40  10034   1191       242
# 4           3522 2025-04-28 10:50:40   9889   1858       477
# ...          ...                 ...    ...    ...       ...
# 122395      2902 2024-12-14 10:50:40   9853   1673       147
# 122396      3890 2024-07-13 10:50:40  10128   1709        63
# 122397      3934 2024-06-10 10:50:40  10267    700         0
# 122398      4260 2024-12-22 10:50:40  10240   1616       106
# 122399      1056 2024-06-25 10:50:40   9931    770         0
#
#         watch_time_minutes  video_length_minutes  subscribers  category  \
# 0             26497.214184              2.862137       228086         1
# 1             15209.747445             23.738069       736015         2
# ...

# %%
import pandas as pd

df = pd.read_csv(r"..\Data\youtube_ad_revenue_dataset.csv")
df
# Out:
#         video_id                        date  views   likes  comments  \
# 0       vid_3092  2024-09-24 10:50:40.993199   9936  1221.0     320.0
# 1       vid_3459  2024-09-22 10:50:40.993199  10017   642.0     346.0
# 2       vid_4784  2024-11-21 10:50:40.993199  10097  1979.0     187.0
# 3       vid_4078  2025-01-28 10:50:40.993199  10034  1191.0     242.0
# 4       vid_3522  2025-04-28 10:50:40.993199   9889  1858.0     477.0
# ...          ...                         ...    ...     ...       ...
# 122395  vid_2902  2024-12-14 10:50:40.993199   9853  1673.0     147.0
# 122396  vid_3890  2024-07-13 10:50:40.993199  10128  1709.0      63.0
# 122397  vid_3934  2024-06-10 10:50:40.993199  10267   700.0       NaN
# 122398  vid_4260  2024-12-22 10:50:40.993199  10240  1616.0     106.0
# 122399  vid_1056  2024-06-25 10:50:40.993199   9931   770.0       NaN
#
#         watch_time_minutes  video_length_minutes  subscribers       category  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
df_copy = df.copy()

# Handle missing values
df_copy=df_copy.dropna(subset=['likes','comments','watch_time_minutes'], how='all') 
df_copy=df_copy.dropna(subset=['likes','comments'], how='all') 
df_copy=df_copy.fillna({'watch_time_minutes':df_copy['watch_time_minutes'].median()})
df_copy['likes'] = df_copy['likes'].fillna(0)
df_copy['likes'] = df_copy['likes'].astype(int)
df_copy['comments'] = df_copy['comments'].fillna(0)
df_copy['comments'] = df_copy['comments'].astype(int)

# delete the duplicate rows and keep the first occurrence
df_copy=df_copy.drop_duplicates(keep='first')

# Label encoding
encoder =LabelEncoder()
df_copy['category']=pd.to_numeric(encoder.fit_transform(df_copy['category']),errors='coerce')

df_copy=df_copy.drop(columns=['video_id'], axis=1) 
df_copy=df_copy.drop(columns=['date'], axis=1) 
df_copy=df_copy.drop(columns=['country'], axis=1) 
df_copy=df_copy.drop(columns=['device'], axis=1)
    
# Feature engineering
df_copy['engagement_rate'] = (df_copy['likes'] + df_copy['comments']) / df_copy['views']

df_copy.to_csv(r"../Data/Preprocessed_youtube_ad_revenue_dataset.csv", index=False)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119696 entries, 0 to 122399
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   views                 119696 non-null  int64
#  1   likes                 119696 non-null  int64
#  2   comments              119696 non-null  int64
#  3   watch_time_minutes    119696 non-null  float64
#  4   video_length_minutes  119696 non-null  float64
#  5   subscribers           119696 non-null  int64
#  6   category              119696 non-null  int64
#  7   ad_revenue_usd        119696 non-null  float64
#  8   engagement_rate       119696 non-null  float64
# dtypes: float64(4), int64(5)
# memory usage: 9.1 MB

# %%
df_copy.isnull().sum()
# Out:
# views                   0
# likes                   0
# comments                0
# watch_time_minutes      0
# video_length_minutes    0
# subscribers             0
# category                0
# ad_revenue_usd          0
# engagement_rate         0
# dtype: int64

# %%
df_copy.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_copy
# Out:
#         views  likes  comments  watch_time_minutes  video_length_minutes  \
# 0        9936   1221       320        26497.214184              2.862137
# 1       10017    642       346        15209.747445             23.738069
# 2       10097   1979       187        57332.658498             26.200634
# 3       10034   1191       242        31334.517771             11.770340
# 4        9889   1858       477        15665.666434              6.635854
# ...       ...    ...       ...                 ...                   ...
# 122395   9853   1673       147        42075.704885             25.490195
# 122396  10128   1709        63        57563.703040             16.229133
# 122397  10267    700         0        27549.714659             23.822365
# 122398  10240   1616       106        56967.384382              7.753099
# 122399   9931    770         0        38466.837135             27.305703
#
#         subscribers       category  ad_revenue_usd  category_encoded  \
# ...

# %%
df_copy[['category','category_encoded']]
# Out:
#              category  category_encoded
# 0       Entertainment                 1
# 1              Gaming                 2
# 2           Education                 0
# 3       Entertainment                 1
# 4           Education                 0
# ...               ...               ...
# 122395      Education                 0
# 122396          Music                 4
# 122397           Tech                 5
# 122398          Music                 4
# 122399           Tech                 5
#
# [119696 rows x 2 columns]
